# %% [markdown]
# ## Assignment 1
# Pius Carbon \
# Student ID 21159062

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Chapter 2, No. 8

# %% [markdown]
# a)

# %%
from ISLP import load_data
college = load_data('College')
college.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %% [markdown]
# b) can be skipped since the data from the python package is already formatted correctly

# %% [markdown]
# c)

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# d)

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]], figsize=(12, 12), marker='o', hist_kwds={'bins': 20}, s=10, alpha=.8)
plt.show()

# %% [markdown]
# e)

# %%
college.boxplot(column='Outstate', by='Private')
plt.title('Outstate vs Private Tutition')
plt.suptitle('')
plt.xlabel('Private College')
plt.ylabel('Tuition')
plt.show()

# %% [markdown]
# f)

# %%
college['Elite'] = pd.cut(college['Top10perc'], bins=[0,50,100], labels=['No', 'Yes'])

val = college['Elite'].value_counts()

print("There are {} Elite colleges and {} Non-Elite colleges".format(val['Yes'], val['No']))


# plot
college.boxplot(column='Outstate', by='Elite')
plt.title('Outstate vs Elite Tuition')
plt.suptitle('')
plt.xlabel('Elite College')
plt.ylabel('Tuition')
plt.show()
# Out:
# There are 78 Elite colleges and 699 Non-Elite colleges

# %% [markdown]
# g)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

fig = college['Outstate'].plot.hist(ax=ax[0], bins=20, alpha=0.7)
fig = college['Outstate'].plot.hist(ax=ax[1], bins=40, alpha=0.7)

plt.show()

fig, ax = plt.subplots(1, 2, figsize=(12, 6))
fig = college['Apps'].plot.hist(ax=ax[0], bins=20, alpha=0.7)
fig = college['Apps'].plot.hist(ax=ax[1], bins=70, alpha=0.7)

plt.show()

# %% [markdown]
# h)

# %%
college["Acc_Rate"] = college["Accept"] / college["Apps"]
college["Enr_Rate"] = college["Enroll"] / college["Accept"]

pd.plotting.scatter_matrix(college[["Acc_Rate", "Enr_Rate"]], figsize=(12, 12), marker='o', hist_kwds={'bins': 20}, s=10, alpha=.8)
plt.show()

# %% [markdown]
# Findings: I was interested if there is any correlation between acceptance and enrollment rates. First observation I made is that the median of the acceptance rates is higher than the one of the enrollment rate. Looking now at the scatter plots, there is no direct correlation visible. The position of the point cloud indicates that a high acceptance rate can be found at a lot of colleges with low to medium enrollment rate. There is not enough data to answer the question which I originally found interesting: do colleges with a low acceptance rate do have high enrollment rates?

# %% [markdown]
# ### Chapter 2, No. 10

# %%
# load boston dataset as pandas datafra
boston = load_data('Boston')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# b)

# %%
no_rows = boston.shape[0]
no_cols = boston.shape[1]
print("There are {} rows and {} columns in the dataset".format(no_rows, no_cols))
print("The rows represent each one neighborhood in Boston and the columns represent the variables associated with that neighborhoods regarding demographics and crime rate")
# Out:
# There are 506 rows and 13 columns in the dataset
# The rows represent each one neighborhood in Boston and the columns represent the variables associated with that neighborhoods regarding demographics and crime rate

# %% [markdown]
# c)

# %%
pd.plotting.scatter_matrix(boston[["crim", "lstat", "medv"]], figsize=(12, 12), marker='o', hist_kwds={'bins': 20}, s=10, alpha=.8)
plt.show()

# %% [markdown]
# Findings: There is a correlation between the percentage of lower status of population and the median value of owner-occupied homes. If you look for correlations of these two factors with crime, their relationship is not directly obvious from the plots and should be tested using statistical tools beyond pure visual interpretation.

# %% [markdown]
# d)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = boston.corr()

# Display the correlation of each predictor with CRIM
print("Correlation of each predictor with CRIM:")
print(correlation_matrix['crim'].sort_values(ascending=False))

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Boston Dataset')
plt.show()
# Out:
# Correlation of each predictor with CRIM:
# crim       1.000000
# rad        0.625505
# tax        0.582764
# lstat      0.455621
# nox        0.420972
# indus      0.406583
# age        0.352734
# ptratio    0.289946
# chas      -0.055892
# zn        -0.200469
# rm        -0.219247
# dis       -0.379670
# medv      -0.388305
# Name: crim, dtype: float64

# %% [markdown]
# Result: There is high correlation of crime with factors such as rad (index of accessibility) and tax (property tax). The factor rad makes sense, since neighborhoods close to highways usually posess a lower socio-economic status due to the noise pollution. The correlation with tax is harder to explain, perhaps crime happens more often at neighborhoods with more property and therefore more opportunities for theft and robbery.

# %% [markdown]
# e)

# %%
# Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

boston.describe()

# The range of each predictor is as follows:
# - crim: 0.00632 to 88.9762
# - tax: 187 to 711
# - ptratio: 12.6 to 22.0
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Findings: The large difference between the 75%-quantil and the max-value of crime is interesting. Let us look at the Top 10 districts with the highest crime rates:

# %%
crime_districts = boston.sort_values(by='crim', ascending=False).head(10)
crime_districts[['crim']]
# Out:
#         crim
# 380  88.9762
# 418  73.5341
# 405  67.9208
# 410  51.1358
# 414  45.7461
# 404  41.5292
# 398  38.3518
# 427  37.6619
# 413  28.6558
# 417  25.9406

# %% [markdown]
# Looking at the quantiles of the "boston.describe" method again, tax looks way more equally distributed, same goes for ptratio.

# %% [markdown]
# f)

# %%
no = boston[boston["chas"] == 1].count().iloc[0]
print("There are {} neighborhoods bounding the Charles River".format(no))
# Out:
# There are 35 neighborhoods bounding the Charles River

# %% [markdown]
# g)

# %%
med = boston['ptratio'].median()
print("The median pupil-teacher ratio among the neighborhoods is {}%".format(med))
# Out:
# The median pupil-teacher ratio among the neighborhoods is 19.05%

# %% [markdown]
# h)

# %%
min_med = boston['medv'].min()
boston[boston['medv'] == min_med]
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
# 405  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24  666
#
#      ptratio  lstat  medv
# 398     20.2  30.59   5.0
# 405     20.2  22.98   5.0

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# Comments on the ranges: The selected neighborhoods have very high crime rates and the age of the houses is very old. The distance to the unemployment centres is low. These factors indicate that these areas have very low socio-economic status

# %% [markdown]
# i)

# %%
more_than_7 = boston[boston['rm'] > 7].count().iloc[0] 
more_than_8 = boston[boston['rm'] > 8].count().iloc[0]
avg_value = boston[boston['rm'] > 8]["medv"].mean()

print("There are {} neighborhoods where the average number of rooms per dwelling is more than 7".format(more_than_7))
print("There are {} neighborhoods where the average number of rooms per dwelling is more than 8".format(more_than_8))
print("The neighborhoods with more than 8 rooms per dwelling are considered to be wealthy neighborhoods, with an average median value of ${} thousand".format(avg_value))
# Out:
# There are 64 neighborhoods where the average number of rooms per dwelling is more than 7
# There are 13 neighborhoods where the average number of rooms per dwelling is more than 8
# The neighborhoods with more than 8 rooms per dwelling are considered to be wealthy neighborhoods, with an average median value of $44.2 thousand

# %% [markdown]
# ## Chapter 3, No. 8

# %% [markdown]
# a)

# %%
auto = load_data('Auto')
auto.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %%
import statsmodels.api as sm

X = auto['horsepower']
y = auto['mpg']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):           7.03e-81
# Time:                        20:11:34   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %%
prediction_for_98 = model.predict([1, 98])
print("The predicted mpg for a car with 98 horsepower is {} mpg".format(prediction_for_98[0]))

# get 95% confidence and prediction interval
import numpy as np
prediction = model.get_prediction([1, 98])
result = prediction.summary_frame(alpha=0.05)
lower = result['mean_ci_lower'][0]
upper = result['mean_ci_upper'][0]
print("The 95% confidence interval for the predicted mpg for a car with 98 horsepower is [{}, {}]".format(lower, upper))
# Out:
# The predicted mpg for a car with 98 horsepower is 24.467077152512424 mpg
# The 95% confidence interval for the predicted mpg for a car with 98 horsepower is [23.97307896070394, 24.961075344320907]

# %% [markdown]
# i. Is there a relationship between the predictor and the response?
#
# Yes there is, described by the value of the coefficient of horsepower. Looking at the R-squared-value, we can tell that the relationship is moderate to strong. The F-Value assures us that the model is a good fit to the underlying data.
#
#
# ii. How strong is the relationship between the predictor and
# the response?
#
# The R-squared value is 0.606 which means that 60.6% of the variance in mpg can be explained by the variable horsepower.
#
#
# iii. Is the relationship between the predictor and the response
# positive or negative?
#
# By looking at the coefficient of horspower one can determine that it is negative which implies that a decrease in horsepower correlates with an increase in mpg.
#
# iv. What is the predicted mpg associated with a horsepower of
# 98? What are the associated 95 % confidence and prediction
# intervals?
#
# Using the coefficient of horsepower we have a predicted 24.467077152512424 mpg. The 95% confidence interval for the predicted mpg for a car with 98 horsepower is [23.97307896070394, 24.961075344320907]

# %% [markdown]
# b)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.scatter(auto['horsepower'], auto['mpg'])
ax.set_xlabel('Horsepower')
ax.set_ylabel('MPG')
ax.set_title('Horsepower vs MPG')
ax.axline((0, model.params.iloc[0]), slope=model.params.iloc[1], color='red')
plt.show()

# %% [markdown]
# c)

# %%
fig, ax = plt.subplots()
ax.scatter(model.fittedvalues, model.resid)
ax.set_xlabel('Fitted values')
ax.set_ylabel('Residuals')
ax.set_title('Fitted values vs Residuals')
plt.show()


infl = model.get_influence()
fig, ax = plt.subplots()
ax.scatter(np.arange(auto.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
ax.set_title('Index vs Leverage')
plt.show()

# %% [markdown]
# The first plot indicates a nonlinear regime for which our fitted linear regression is not the best model to describe. In the second plot you notice that there is a dozens of points that have way higher leverage than the others. This indicates that the regression line is influenced by them leading to a possible invalidation of the whole fit

# %% [markdown]
# ## Chapter 3, No. 9

# %% [markdown]
# a)

# %%
pd.plotting.scatter_matrix(auto, figsize=(12, 12), marker='o', hist_kwds={'bins': 20}, s=10, alpha=.8)
plt.show()

# %% [markdown]
# b)

# %%
auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %% [markdown]
# c)

# %%
X = auto.drop("mpg", axis=1)
mv_model = sm.OLS(auto['mpg'], X).fit()
mv_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.981
# Method:                 Least Squares   F-statistic:                              2933.
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        20:11:39   Log-Likelihood:                         -1030.4
# No. Observations:                 392   AIC:                                      2075.
# Df Residuals:                     385   BIC:                                      2103.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# i. Is there a relationship between the predictors and the response? Use the anova_lm() function from statsmodels to
# answer this question.
#
# Looking at the F-statistic one can see that its value indicate that the predictors have a relationship with the response. So we can reject the null-hypothesis.
#
# ii. Which predictors appear to have a statistically signifcant relationship to the response?
#
# By looking at the p-values one can determine that weight, year and origin have a significant relationship. Depending on the significance level displacement as well.
#
# iii. What does the coefficient for the year variable suggest?
#
# Its value of 0.58 suggest that for every year, there is an increase of 0.58 units in mpg.

# %% [markdown]
# d)

# %%
# plot residual plot
fig, ax = plt.subplots()
ax.scatter(mv_model.fittedvalues, mv_model.resid)
ax.set_xlabel('Fitted values')
ax.set_ylabel('Residuals')
ax.set_title('Fitted values vs Residuals')
plt.show()

# plot leverage plot
fig, ax = plt.subplots()
ax.scatter(np.arange(auto.shape[0]), infl.hat_matrix_diag)
ax.set_xlabel('Index')
ax.set_ylabel('Leverage')
ax.set_title('Index vs Leverage')
plt.show()

# %% [markdown]
# Both plots suggest that there is non-linearity in the data: the residual plot is curved which suggests using a nonlinear model for a better fit.  The leverage plot shows that there are some data points with smaller indices with high leverage, which may be influencing the model fit.

# %% [markdown]
# e)

# %%
X = auto.drop("mpg", axis=1)
X['horsepower:cylinders'] = X['horsepower'] * X['cylinders']
interaction_model = sm.OLS(auto['mpg'], X).fit()
interaction_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.986
# Model:                            OLS   Adj. R-squared (uncentered):              0.986
# Method:                 Least Squares   F-statistic:                              3398.
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        20:11:39   Log-Likelihood:                         -975.77
# No. Observations:                 392   AIC:                                      1968.
# Df Residuals:                     384   BIC:                                      1999.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# This interaction (horsepower * cylinders) seems to be statistically significant.

# %% [markdown]
# f)

# %%
X_log = auto.drop("mpg", axis=1).apply(np.log)
log_model = sm.OLS(auto['mpg'], X_log).fit()
log_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.984
# Model:                            OLS   Adj. R-squared (uncentered):              0.984
# Method:                 Least Squares   F-statistic:                              3453.
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        20:11:39   Log-Likelihood:                         -998.94
# No. Observations:                 392   AIC:                                      2012.
# Df Residuals:                     385   BIC:                                      2040.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# This model is a good fit for the data and even more variables contribute to explain the response.

# %%
X_sqrt = auto.drop("mpg", axis=1).apply(np.sqrt)
sqrt_model = sm.OLS(auto['mpg'], X_sqrt).fit()
sqrt_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.982
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              3034.
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                        0.00
# Time:                        20:11:39   Log-Likelihood:                         -1023.9
# No. Observations:                 392   AIC:                                      2062.
# Df Residuals:                     385   BIC:                                      2090.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# This fit is significant put depends on different variables as the previous one.

# %%
X_sq = auto.drop("mpg", axis=1).apply(np.square)
sq_model = sm.OLS(auto['mpg'], X_sq).fit()
sq_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared (uncentered):                   0.980
# Model:                            OLS   Adj. R-squared (uncentered):              0.980
# Method:                 Least Squares   F-statistic:                              2680.
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                   3.95e-322
# Time:                        20:11:39   Log-Likelihood:                         -1047.8
# No. Observations:                 392   AIC:                                      2110.
# Df Residuals:                     385   BIC:                                      2137.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# This model is still a good fit for the data put encounters issues arising from multicollinearity in the data.

# %% [markdown]
# ### Additional coding task for bias-variance trade-off

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression

ntrain = 50 # Training
ntest = 500 # Test
nrep = 100 # repeat 100 times
p = 20
puse = np.array([1, 2, 3, 4, 10, 20]) # number of predictors
k = np.arange(1 ,10)

sigma = 0.5

Xtrain = np.random.uniform(-1, 1, [ntrain,p])
Xtest = np.random.uniform(-1, 1, [ntest,p])
y0 = np.sin(2 * Xtrain[:, 0]) # Only the first predictor is related to y
ytest = np.sin(2 * Xtest[:, 0])

out_knn = pd.DataFrame() # Output results
out_lm = pd.DataFrame()

for i in np.arange(0, len(puse)):
    yhat_lm = np.zeros((ntest, nrep))
    yhat_knn = np.zeros((ntest, nrep, len(k)))
    
    for l in np.arange(0, nrep):
        y = y0 + np.random.normal(0, sigma, ntrain)

        fit_lm = LinearRegression()
        fit_knn = KNeighborsRegressor()
    
        ######### DO: fit linear regression using LinearRegression funciton, assign predicted value to yhat_lm[:, [l]] #########
        fit_lm = fit_lm.fit(Xtrain[:, 0:puse[i]], y)
        yhat_lm[:, l] = fit_lm.predict(Xtest[:, 0:puse[i]]) # Predicted value
      
    
        for j in np.arange(0, len(k)):
            ######### DO: fit knn using KNeighborsRegressor funciton, assign predicted value to yhat_knn[:, l, j] #########
            fit_knn = KNeighborsRegressor(n_neighbors=k[j])
            fit_knn = fit_knn.fit(Xtrain[:, 0:puse[i]], y)
            yhat_knn[:, l, j] = fit_knn.predict(Xtest[:, 0:puse[i]]) # Predicted value
        
        print(i + 1, "-th p, ", l + 1, "-th repetition finished. \n")
    
  
    ######### DO: compute bias and variance of linear regression #########
    
    # Compute mean of predicted values
    ybar_lm = np.mean(yhat_lm, axis=1) # E(f^hat)
    
    # Compute bias^2
    biasSQ_lm = np.mean((ytest - ybar_lm)**2) # E[ (f - E(f^hat))^2 ]
    
    # Compute variance
    variance_lm = np.mean(np.var(yhat_lm, axis=1))# E[ (E(f^hat) - f^hat)^2 ]
    
    # Compute total MSE
    err_lm = biasSQ_lm + variance_lm

    out_lm = pd.concat([out_lm, pd.DataFrame({'error': [biasSQ_lm], 'component': ['squared-bias'], 'p': [f"p = {puse[i]}"]})])
    out_lm = pd.concat([out_lm, pd.DataFrame({'error': [variance_lm], 'component': ['variance'], 'p': [f"p = {puse[i]}"]})])
    out_lm = pd.concat([out_lm, pd.DataFrame({'error': [err_lm], 'component': ['MSE'], 'p': [f"p = {puse[i]}"]})])
    
    ######### DO: compute bias and variance of knn regression #########
    
    # Compute mean of predicted values
    ybar_knn = np.mean(yhat_knn, axis=1)# E(f^hat)
    
    # Compute bias^2
    diff = (np.tile(ytest, (9, 1)).T - ybar_knn)**2
    biasSQ_knn = np.mean(diff, axis=0) # E[ (f - E(f^hat))^2 ]
    
    # Compute variance
    variance_knn = np.mean(np.var(yhat_knn, axis=1))# E[ (E(f^hat) - f^hat)^2 ]
    
    # Compute total MSE
    err_knn = biasSQ_knn + variance_knn

    out_knn = pd.concat([out_knn, pd.DataFrame({'error': biasSQ_knn, 'component': ['squared-bias'] * len(k), 'K': 1 / np.array(k),
                                        'p': [f"p = {puse[i]}"] * len(k)})])
    
    out_knn = pd.concat([out_knn, pd.DataFrame({'error': variance_knn, 'component': ['variance'] * len(k), 'K': 1 / np.array(k),
                                        'p': [f"p = {puse[i]}"] * len(k)})])
    
    out_knn = pd.concat([out_knn, pd.DataFrame({'error': err_knn, 'component': ['MSE'] * len(k), 'K': 1 / np.array(k),
                                        'p': [f"p = {puse[i]}"] * len(k)})])
# Out:
# 1 -th p,  1 -th repetition finished.
#
# 1 -th p,  2 -th repetition finished.
#
# 1 -th p,  3 -th repetition finished.
#
# 1 -th p,  4 -th repetition finished.
#
# 1 -th p,  5 -th repetition finished.
#
# 1 -th p,  6 -th repetition finished.
#
# 1 -th p,  7 -th repetition finished.
#
# 1 -th p,  8 -th repetition finished.
#
# 1 -th p,  9 -th repetition finished.
#
# 1 -th p,  10 -th repetition finished.
#
# 1 -th p,  11 -th repetition finished.
#
# 1 -th p,  12 -th repetition finished.
#
# 1 -th p,  13 -th repetition finished.
#
# 1 -th p,  14 -th repetition finished.
#
# 1 -th p,  15 -th repetition finished.
#
# 1 -th p,  16 -th repetition finished.
#
# 1 -th p,  17 -th repetition finished.
#
# 1 -th p,  18 -th repetition finished.
#
# 1 -th p,  19 -th repetition finished.
#
# 1 -th p,  20 -th repetition finished.
#
# 1 -th p,  21 -th repetition finished.
#
# 1 -th p,  22 -th repetition finished.
#
# 1 -th p,  23 -th repetition finished.
#
# 1 -th p,  24 -th repetition finished.
#
# ...

# %% [markdown]
# ### Plot of Test MSE for linear regression and KNN

# %%
fig, axes = plt.subplots(1, len(puse), figsize=(20, 5))

for idx, p_val in enumerate(puse):
    mse_knn = out_knn[(out_knn['component'] == 'MSE') & (out_knn['p'] == f"p = {p_val}")]
    mse_lm = out_lm[(out_lm['component'] == 'MSE') & (out_lm['p'] == f"p = {p_val}")]
    axes[idx].plot(mse_knn['K'], mse_knn['error'], label='KNN')
    # plot horizontal line for linear regression
    arr = np.array([mse_lm['error'].iloc[0]] * len(mse_knn['K']))
    axes[idx].plot(mse_knn['K'], arr, label='Linear Regression')
    axes[idx].set_title(f"p = {p_val}")
    axes[idx].set_xlabel('1/K')
    axes[idx].set_ylabel('MSE')
    axes[idx].legend()
    axes[idx].grid()

# %% [markdown]
# ### Plot of the bias-variance tradeoff for linear regression and KNN

# %%
# Plot the results
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

sns.lineplot(data=out_lm, x='p', y='error', hue='component', ax=ax[0])
ax[0].set_title('Linear Regression')
ax[0].set_ylabel('Error')
ax[0].set_yscale('log')

sns.lineplot(data=out_knn, x='K', y='error', hue='component', style='p', ax=ax[1])
ax[1].set_title('KNN Regression')

plt.show()
